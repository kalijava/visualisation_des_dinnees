# %%
# creation d un simple graphique
# importation de la bibliotheque
import matplotlib.pyplot as mp
# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]
#plotting the data
mp.plot(x,y)
# Adding title to the plot
mp.title("linear graph",fontsize=25,color="green")
# Adding label on the y-axis
mp.ylabel("y-axis")
# adding label on the x-axis
mp.ylabel("x-axis")
# setting the labels of x-axis
mp.xticks(x,labels=["tony","l`immense_mr_z","jospin","chaldo"])
mp.legend(["reussite_"])
mp.show()

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

fig = plt.figure(figsize = (5, 4))

# Adding the axes to the figure
ax = fig.add_axes([1, 1, 1, 1])

# plotting 1st dataset to the figure
ax1 = ax.plot(x, y)

# plotting 2nd dataset to the figure
ax2 = ax.plot(y, x)

# Setting Title
ax.set_title("Linear Graph")

# Setting Label
ax.set_xlabel("X-Axis")
ax.set_ylabel("Y-Axis")

# Adding Legend
ax.legend(labels = ['line 1', 'line 2'])

plt.show()

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# Creating a new figure with width = 5 inches
# and height = 4 inches
fig = plt.figure(figsize =(5, 4))

# Creating first axes for the figure
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# Creating second axes for the figure
ax2 = fig.add_axes([1, 0.1, 0.8, 0.8])

# Adding the data to be plotted
ax1.plot(x, y)
ax2.plot(y, x)

plt.show()

# %%
#differents types de traces


#1: graphine en ligne


import matplotlib.pyplot as plt
#linewidth:definir largeur d une ligne
#marker:definir les marker d un point
#markersize:definir la taille des marker
#linestyle:pour definir le style de tracer

# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# plotting the data
plt.plot(x, y, color='green', linewidth=3, marker='s',
markersize=15, linestyle=':')

# Adding title to the plot
plt.title("Line Chart")

# Adding label on the y-axis
plt.ylabel('Y-Axis')

# Adding label on the x-axis
plt.xlabel('X-Axis')

plt.show()

# %%
#2:graphique en barre

# %%
import matplotlib.pyplot as plt
#edgecolor:coleur du bord des barres

x = [10, 20, 30, 40,20,10,10]

# plotting the data
plt.hist(x, bins=7, color='green', edgecolor='blue',
linestyle=':', alpha=1)

# Adding title to the plot
plt.title("Tips Dataset")

# Adding label on the y-axis
plt.ylabel('Frequency')

# Adding label on the x-axis
plt.xlabel('Total Bill')

plt.show()

# %%
# 3 nuages de point

import matplotlib.pyplot as plt
import pandas as pd

data=pd.read_csv("test.csv")

xx=data["First Name"]
print(xx)
yy=data["Salary"]
print(yy)
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]





# plotting the data
plt.scatter(x, y)

# Adding title to the plot
plt.title("Tips Dataset")

# Adding label on the y-axis
plt.ylabel('Total Bill')

# Adding label on the x-axis
plt.xlabel('Day')

plt.show()
# Out:
# 0      Douglas
# 1       Thomas
# 2        Maria
# 3        Jerry
# 4        Larry
#         ...
# 995      Henry
# 996    Phillip
# 997    Russell
# 998      Larry
# 999     Albert
# Name: First Name, Length: 1000, dtype: object
# 0       97308
# 1       61933
# 2      130590
# 3      138705
# 4      101004
#         ...
# 995    132483
# 996     42392
# 997     96914
# 998     60500
# 999    129949
# Name: Salary, Length: 1000, dtype: int64

# %%
print("la statistiques est la grammaire de la science de donnee")
# Out:
# la statistiques est la grammaire de la science de donnee
